# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading dataset
data = pd.read_csv(r"C:\Users\HP\Documents\icttek\iris.csv")

# %%
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
#Display the columns of the Dataset
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
#calculate the mean
data['SL'].mean()
# Out:
# 5.843333333333334

# %%
data['SW'].mean()
# Out:
# 3.0540000000000003

# %%
data['PL'].mean()
# Out:
# 3.758666666666666

# %%
data['PW'].mean()
# Out:
# 1.1986666666666668

# %%
# check for null values
data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
# Bar Graph 
plt.figure(figsize=(10,6)) 
plt.barh(data['SL'],data['SW'],data['PL'],data['PW'])
plt.show()

# %%
sns.boxplot(data)
plt.show()

# %%
# Line Graph
plt.plot(data['SL'],label = 'SL',linestyle="dashed",color="green",linewidth = 2)
plt.plot(data['SW'],label = 'SW',linestyle="dotted",color="red",linewidth = 2)
plt.plot(data['PL'],label = 'PL',linestyle="dashed",color="brown",linewidth = 2)
plt.plot(data['PW'],label = 'PW',linestyle=":",color="blue",linewidth = 2)
plt.title('Line Graph')
plt.xlabel('X-Value')
plt.ylabel('Y-Value')
plt.legend() 
plt.show()

# %%
plt.boxplot(data['SL'])
plt.show()

# %%
plt.boxplot(data['SW'])
plt.show()

# %%
plt.boxplot(data['PL'])
plt.show()

# %%
plt.boxplot(data['PW'])
plt.show()
